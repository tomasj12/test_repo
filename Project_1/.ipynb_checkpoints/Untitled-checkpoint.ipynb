# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print('ajajajaja')

# %%
rdn = np.random.randint(10,15,100)
plt.plot(rdn)
plt.show()

# %%
print('pridal som')
# Out:
# pridal som

# %%
print('pridal som')

# %%
print('pridal som')

# %%
print('caaau')

# %%
print('pridal som')
# Out:
# pridal som

# %%
print('pridal som znova')
# Out:
# pridal som znova

# %%
import numpy as np

# %%
print('ou je')

# %%
# !conda env export > environment.yaml

# %%
print('ddsds')

# %%
print('ddsds')

# %%
print('dsdsdsdsds')

# %%
print('som kokot')

# %%
print('dsdsdsds')
